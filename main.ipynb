# %%
##### This script should run everything, from recording to analysis
##### Stages:
##### 1) Recording
#####   a) Pulse oximeter readings, generating paired timing and amplitude data
#####   b) Audio data from the scanner - we're going to pretend that we did this as it'll take too long
##### 2) Analysis
#####   a) Audio waveform identification of onset and chunking - label timepoints when the sequence starts, likewise when individual blocks within it are
#####   b) Pulse oximeter waveform peak detection / attribution of specific cardiac phase

# %%
#import record_audio
from importlib import reload
import sys
if not('Getting_Pulse_signal_from_ardino.logging' in sys.modules):
    import Getting_Pulse_signal_from_ardino.logging
else:
    reload(Getting_Pulse_signal_from_ardino.logging)
# Out:
# Signal: 357, Time: 1511204,Funny Number: 4222
# Signal: 359, Time: 1512204,Funny Number: 4222
# Signal: 355, Time: 1513204,Funny Number: 4222
# Signal: 352, Time: 1514204,Funny Number: 4222
# Signal: 355, Time: 1515204,Funny Number: 4222
# Signal: 359, Time: 1516204,Funny Number: 4222
# Signal: 355, Time: 1517204,Funny Number: 4222
# Signal: 357, Time: 1518204,Funny Number: 4222
# Signal: 357, Time: 1519204,Funny Number: 4222
# Signal: 358, Time: 1520204,Funny Number: 4222
# Closing
# logging finished

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module '_frozen_importlib' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  '_io': <module '_io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' (frozen)>,
#  'encodings.aliases': <module 'encodings.aliases' from 'C:\\Users\\c1869192\\AppData\\Local\\anaconda3\\envs\\retromatch\\Lib\\encodings\\aliases.py'>,
# ...

# %%
if (1 in [1,0]):
    print("hi")
else:
    print("no")
# Out:
# hi
